# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Aid_aggregate_data.xlsx')

# %%
df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# 5     Afghanistan          AFG
# 6     Afghanistan          AFG
# 7     Afghanistan          AFG
# 8     Afghanistan          AFG
# 9     Afghanistan          AFG
# 10    Afghanistan          AFG
# 11    Afghanistan          AFG
# 12    Afghanistan          AFG
# 13    Afghanistan          AFG
# 14    Afghanistan          AFG
# 15    Afghanistan          AFG
# 16    Afghanistan          AFG
# 17        Albania          ALB
# 18        Albania          ALB
# 19        Albania          ALB
# 20        Albania          ALB
# 21        Albania          ALB
# 22        Albania          ALB
# 23        Albania          ALB
# 24        Albania          ALB
# 25        Albania          ALB
# 26        Albania          ALB
# 27        Albania          ALB
# 28        Albania          ALB
# ...

# %%
df['Indicator Name'][1]
# Out:
# 'Net official development assistance and official aid received (current US$)'

# %%
#Output index numbers
df.index
# Out:
# RangeIndex(start=0, stop=4488, step=1)

# %%
#Output column names
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')

# %%
#Select Column 1960
df.loc[:,'1960']
# Out:
# 0       3.637000e+02
# 1       1.718000e+07
# 2                NaN
# 3                NaN
# 4       5.977733e+01
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15      1.909663e+00
# 16      8.996351e+06
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
#             ...
# 4458    2.341662e+02
# 4459             NaN
# 4460             NaN
# 4461             NaN
# 4462             NaN
# 4463             NaN
# 4464             NaN
# 4465             NaN
# 4466             NaN
# 4467             NaN
# 4468             NaN
# 4469    3.021499e-01
# ...

# %%
#Select Second Row
df.loc[1,:]
# Out:
# Country Name                                            Afghanistan
# Country Code                                                    AFG
# Indicator Name    Net official development assistance and offici...
# Indicator Code                                       DT.ODA.ALLD.CD
# 1960                                                      1.718e+07
# 1961                                                      3.467e+07
# 1962                                                      1.693e+07
# 1963                                                      3.667e+07
# 1964                                                      4.617e+07
# 1965                                                      5.393e+07
# 1966                                                      5.036e+07
# 1967                                                       4.06e+07
# 1968                                                      2.924e+07
# 1969                                                      2.725e+07
# ...

# %%
#Select Second Row, starting from 1960 onwards
df.loc[1,'1960':]
# Out:
# 1960      1.718e+07
# 1961      3.467e+07
# 1962      1.693e+07
# 1963      3.667e+07
# 1964      4.617e+07
# 1965      5.393e+07
# 1966      5.036e+07
# 1967       4.06e+07
# 1968      2.924e+07
# 1969      2.725e+07
# 1970      2.761e+07
# 1971      4.444e+07
# 1972      5.518e+07
# 1973      5.595e+07
# 1974      4.918e+07
# 1975      6.945e+07
# 1976      7.143e+07
# 1977      8.561e+07
# 1978      8.252e+07
# 1979     1.0547e+08
# 1980      3.301e+07
# 1981      2.391e+07
# 1982       9.33e+06
# 1983      1.328e+07
# 1984        6.5e+06
# 1985      1.632e+07
# 1986       1.91e+06
# 1987      4.528e+07
# 1988      7.236e+07
# 1989     1.4832e+08
# 1990     1.2172e+08
# 1991     5.0753e+08
# 1992      2.049e+08
# 1993      2.238e+08
# 1994     2.2642e+08
# 1995     2.1253e+08
# 1996     1.6963e+08
# 1997     2.3075e+08
# 1998      1.642e+08
# 1999     1.4286e+08
# 2000     1.3601e+08
# 2001     4.1036e+08
# 2002    1.30977e+09
# 2003    1.59367e+09
# 2004    2.31064e+09
# ...

# %%
#Iterate through each element in the specified row/column pair
for index, row in df.iterrows() :
    print(row[0], row[20])
# Out:
# Afghanistan 270.6
# Afghanistan 71430000.0
# Afghanistan nan
# Afghanistan nan
# Afghanistan 199.02617272905144
# Afghanistan 103.45
# Afghanistan nan
# Afghanistan 84.0
# Afghanistan nan
# Afghanistan nan
# Afghanistan 12.115920718071257
# Afghanistan nan
# Afghanistan nan
# Afghanistan nan
# Afghanistan nan
# Afghanistan 5.562954569827385
# Afghanistan 12840299.0
# Albania nan
# Albania nan
# Albania nan
# Albania nan
# Albania nan
# Albania 77.04
# Albania nan
# Albania 52.75
# Albania nan
# Albania nan
# Albania 20.985401459854014
# Albania nan
# Albania nan
# Albania nan
# Albania nan
# Albania nan
# Albania 2458526.0
# Algeria 194.1
# Algeria 145370000.0
# Algeria nan
# Algeria nan
# Algeria 1031.303135168394
# Algeria 40.16
# Algeria nan
# Algeria 37.08
# Algeria nan
# Algeria nan
# Algeria 2.977654991728736
# Algeria nan
# Algeria nan
# Algeria nan
# Algeria 0.0
# Algeria 8.456543274354708
# Algeria 17190239.0
# American Samoa nan
# American Samoa nan
# American Samoa nan
# ...

# %%
#Count number of non-NaN values in certain column
print (df['1960'].count())
print (df['2015'].count())
# Out:
# 809
# 1977

# %%
#Max amount of aid received Afghanistan
df.loc[1,'1960':].max()
# Out:
# 6867050000.0

# %%
#Median amount of aid received Afghanistan
df.loc[1,'1960':].median()
# Out:
# 95540000.0

# %%
#Country List
df['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Arab World', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic',
# ...

# %%
# Output net official development assistance data
assistance = df.loc[df['Indicator Name'] == 'Net official development assistance and official aid received (current US$)']
assistance
# Out:
#                   Country Name Country Code  \
# 1                  Afghanistan          AFG
# 18                     Albania          ALB
# 35                     Algeria          DZA
# 52              American Samoa          ASM
# 69                     Andorra          AND
# 86                      Angola          AGO
# 103        Antigua and Barbuda          ATG
# 120                 Arab World          ARB
# 137                  Argentina          ARG
# 154                    Armenia          ARM
# 171                      Aruba          ABW
# 188                  Australia          AUS
# 205                    Austria          AUT
# 222                 Azerbaijan          AZE
# 239               Bahamas, The          BHS
# 256                    Bahrain          BHR
# 273                 Bangladesh          BGD
# 290                   Barbados          BRB
# 307                    Belarus          BLR
# 324                    Belgium          BEL
# ...

# %%
assistance_plt = assistance.set_index('Country Name') # Ste index as country names
assistance_plt = assistance_plt.loc[:,'1960':] # Select data from 1960 onwards
assistance_plt
# Out:
#                                   1960          1961          1962  \
# Country Name
# Afghanistan               1.718000e+07  3.467000e+07  1.693000e+07
# Albania                            NaN           NaN           NaN
# Algeria                   3.550500e+08  4.379100e+08  3.976300e+08
# American Samoa                     NaN           NaN           NaN
# Andorra                            NaN           NaN           NaN
# Angola                   -5.000000e+04  2.355000e+07           NaN
# Antigua and Barbuda                NaN           NaN           NaN
# Arab World                8.819900e+08  9.739300e+08  9.290900e+08
# Argentina                 2.858000e+07  2.918000e+07  3.980000e+07
# Armenia                            NaN           NaN           NaN
# Aruba                              NaN           NaN           NaN
# Australia                          NaN           NaN           NaN
# Austria                            NaN           NaN           NaN
# ...

# %%
assistance_plt = assistance_plt.T # Transpose / swap axis
ax = assistance_plt.plot(legend=None, figsize=(20,10))
ax.set_xlabel("Year")
ax.set_ylabel("Net development assistance aid received (current US$)")
plt.show(ax)
